# %% [markdown]
# Data from https://openrepair.org/open-data/downloads/
#
# (Source: https://openrepair.org/news/open-repair-alliance-dataset-increases-to-81000-records-of-community-repair/)

# %%
import polars as pl

pl.Config.set_fmt_str_lengths(100)
# Out:
# polars.cfg.Config

# %%
df = pl.read_csv(
    "../data/01_raw/OpenRepairData_v0.3_aggregate_202210.csv",
    dtypes={
        "product_age": pl.Float64,
        "group_identifier": pl.Utf8,
    },
    parse_dates=True,
)
df.head()
# Out:
# shape: (5, 14)
# ┌─────────┬────────────┬─────────┬────────────┬─────┬────────────┬────────────┬──────────┬─────────┐
# │ id      ┆ data_provi ┆ country ┆ partner_pr ┆ ... ┆ repair_bar ┆ group_iden ┆ event_da ┆ problem │
# │ ---     ┆ der        ┆ ---     ┆ oduct_cate ┆     ┆ rier_if_en ┆ tifier     ┆ te       ┆ ---     │
# │ str     ┆ ---        ┆ str     ┆ gory       ┆     ┆ d_of_life  ┆ ---        ┆ ---      ┆ str     │
# │         ┆ str        ┆         ┆ ---        ┆     ┆ ---        ┆ str        ┆ date     ┆         │
# │         ┆            ┆         ┆ str        ┆     ┆ str        ┆            ┆          ┆         │
# ╞═════════╪════════════╪═════════╪════════════╪═════╪════════════╪════════════╪══════════╪═════════╡
# │ anstift ┆ anstiftung ┆ DEU     ┆ Elektro    ┆ ... ┆ null       ┆ 5073       ┆ 2012-06- ┆ Funktio │
# │ ung_274 ┆            ┆         ┆ divers ~   ┆     ┆            ┆            ┆ 20       ┆ nierte  │
# │ 9       ┆            ┆         ┆ Nähmaschin ┆     ┆            ┆            ┆          ┆ nicht   │
# │         ┆            ┆         ┆ e          ┆     ┆            ┆            ┆          ┆ mehr.   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ Fehler  │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ und     │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ Lösung  │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ nicht   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ dokumen │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ tiert.  │
# │ anstift ┆ anstiftung ┆ DEU     ┆ Computer ~ ┆ ... ┆ null       ┆ 5073       ┆ 2012-06- ┆ Wurde   │
# │ ung_275 ┆            ┆         ┆ Laptop     ┆     ┆            ┆            ┆ 20       ┆ schnell │
# │ 0       ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ heiß.   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ Der     │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ Lüfter  │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ war     │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ sehr    │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ verschm │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ utzt,   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ wurde   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ gereini │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ gt. Das │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ nächste │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ Mal     │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ müssen  │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ wir     │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ noc...  │
# │ anstift ┆ anstiftung ┆ DEU     ┆ Computer ~ ┆ ... ┆ null       ┆ 5073       ┆ 2012-06- ┆ Funktio │
# │ ung_274 ┆            ┆         ┆ Drucker    ┆     ┆            ┆            ┆ 20       ┆ nierte  │
# │ 6       ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ nicht   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ mehr.   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ Fehler  │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ und     │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ Lösung  │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ nicht   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ dokumen │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ tiert.  │
# │ anstift ┆ anstiftung ┆ DEU     ┆ Unterhaltu ┆ ... ┆ null       ┆ 5073       ┆ 2012-06- ┆ Funktio │
# │ ung_274 ┆            ┆         ┆ ngselektro ┆     ┆            ┆            ┆ 20       ┆ nierte  │
# │ 7       ┆            ┆         ┆ nik ~      ┆     ┆            ┆            ┆          ┆ nicht   │
# │         ┆            ┆         ┆ Kopfhörer  ┆     ┆            ┆            ┆          ┆ mehr.   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ Fehler  │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ und     │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ Lösung  │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ nicht   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ dokumen │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ tiert.  │
# │ anstift ┆ anstiftung ┆ DEU     ┆ Haushaltsg ┆ ... ┆ null       ┆ 5073       ┆ 2012-09- ┆ Die     │
# │ ung_274 ┆            ┆         ┆ eräte ~    ┆     ┆            ┆            ┆ 19       ┆ Beine   │
# │ 2       ┆            ┆         ┆ Spielzeug  ┆     ┆            ┆            ┆          ┆ der     │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ Puppe   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ waren   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ ab. Sie │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ waren   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ mit     │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ Fäden   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ an der  │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ Hüfte   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ befesti │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ gt,     │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ damit   │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ sie     │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ sich    │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ auf     │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ drehen  │
# │         ┆            ┆         ┆            ┆     ┆            ┆            ┆          ┆ ...     │
# └─────────┴────────────┴─────────┴────────────┴─────┴────────────┴────────────┴──────────┴─────────┘

# %%
categories = pl.read_csv("../data/01_raw/OpenRepairData_v0.3_Product_Categories.csv")
categories.head()
# Out:
# shape: (5, 2)
# ┌─────────────────────┬─────────────────────────────┐
# │ product_category_id ┆ product_category            │
# │ ---                 ┆ ---                         │
# │ i64                 ┆ str                         │
# ╞═════════════════════╪═════════════════════════════╡
# │ 1                   ┆ Aircon/dehumidifier         │
# │ 2                   ┆ Battery/charger/adapter     │
# │ 3                   ┆ Decorative or safety lights │
# │ 4                   ┆ Desktop computer            │
# │ 5                   ┆ Digital compact camera      │
# └─────────────────────┴─────────────────────────────┘

# %%
df = df.select(pl.all().exclude("product_category")).join(
    categories, on="product_category_id"
)
df.head()
# Out:
# shape: (5, 14)
# ┌─────────┬────────────┬─────────┬────────────┬─────┬────────────┬──────────┬─────────┬────────────┐
# │ id      ┆ data_provi ┆ country ┆ partner_pr ┆ ... ┆ group_iden ┆ event_da ┆ problem ┆ product_ca │
# │ ---     ┆ der        ┆ ---     ┆ oduct_cate ┆     ┆ tifier     ┆ te       ┆ ---     ┆ tegory     │
# │ str     ┆ ---        ┆ str     ┆ gory       ┆     ┆ ---        ┆ ---      ┆ str     ┆ ---        │
# │         ┆ str        ┆         ┆ ---        ┆     ┆ str        ┆ date     ┆         ┆ str        │
# │         ┆            ┆         ┆ str        ┆     ┆            ┆          ┆         ┆            │
# ╞═════════╪════════════╪═════════╪════════════╪═════╪════════════╪══════════╪═════════╪════════════╡
# │ anstift ┆ anstiftung ┆ DEU     ┆ Elektro    ┆ ... ┆ 5073       ┆ 2012-06- ┆ Funktio ┆ Sewing     │
# │ ung_274 ┆            ┆         ┆ divers ~   ┆     ┆            ┆ 20       ┆ nierte  ┆ machine    │
# │ 9       ┆            ┆         ┆ Nähmaschin ┆     ┆            ┆          ┆ nicht   ┆            │
# │         ┆            ┆         ┆ e          ┆     ┆            ┆          ┆ mehr.   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ Fehler  ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ und     ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ Lösung  ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ nicht   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ dokumen ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ tiert.  ┆            │
# │ anstift ┆ anstiftung ┆ DEU     ┆ Computer ~ ┆ ... ┆ 5073       ┆ 2012-06- ┆ Wurde   ┆ Laptop     │
# │ ung_275 ┆            ┆         ┆ Laptop     ┆     ┆            ┆ 20       ┆ schnell ┆            │
# │ 0       ┆            ┆         ┆            ┆     ┆            ┆          ┆ heiß.   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ Der     ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ Lüfter  ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ war     ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ sehr    ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ verschm ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ utzt,   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ wurde   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ gereini ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ gt. Das ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ nächste ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ Mal     ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ müssen  ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ wir     ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ noc...  ┆            │
# │ anstift ┆ anstiftung ┆ DEU     ┆ Computer ~ ┆ ... ┆ 5073       ┆ 2012-06- ┆ Funktio ┆ Printer/sc │
# │ ung_274 ┆            ┆         ┆ Drucker    ┆     ┆            ┆ 20       ┆ nierte  ┆ anner      │
# │ 6       ┆            ┆         ┆            ┆     ┆            ┆          ┆ nicht   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ mehr.   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ Fehler  ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ und     ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ Lösung  ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ nicht   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ dokumen ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ tiert.  ┆            │
# │ anstift ┆ anstiftung ┆ DEU     ┆ Unterhaltu ┆ ... ┆ 5073       ┆ 2012-06- ┆ Funktio ┆ Headphones │
# │ ung_274 ┆            ┆         ┆ ngselektro ┆     ┆            ┆ 20       ┆ nierte  ┆            │
# │ 7       ┆            ┆         ┆ nik ~      ┆     ┆            ┆          ┆ nicht   ┆            │
# │         ┆            ┆         ┆ Kopfhörer  ┆     ┆            ┆          ┆ mehr.   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ Fehler  ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ und     ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ Lösung  ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ nicht   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ dokumen ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ tiert.  ┆            │
# │ anstift ┆ anstiftung ┆ DEU     ┆ Haushaltsg ┆ ... ┆ 5073       ┆ 2012-09- ┆ Die     ┆ Toy        │
# │ ung_274 ┆            ┆         ┆ eräte ~    ┆     ┆            ┆ 19       ┆ Beine   ┆            │
# │ 2       ┆            ┆         ┆ Spielzeug  ┆     ┆            ┆          ┆ der     ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ Puppe   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ waren   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ ab. Sie ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ waren   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ mit     ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ Fäden   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ an der  ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ Hüfte   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ befesti ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ gt,     ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ damit   ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ sie     ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ sich    ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ auf     ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ drehen  ┆            │
# │         ┆            ┆         ┆            ┆     ┆            ┆          ┆ ...     ┆            │
# └─────────┴────────────┴─────────┴────────────┴─────┴────────────┴──────────┴─────────┴────────────┘

# %%
len(df)
# Out:
# 81189

# %%
df["country"].value_counts().sort("counts", descending=True).head()
# Out:
# shape: (5, 2)
# ┌─────────┬────────┐
# │ country ┆ counts │
# │ ---     ┆ ---    │
# │ str     ┆ u32    │
# ╞═════════╪════════╡
# │ GBR     ┆ 23141  │
# │ NLD     ┆ 22986  │
# │ DEU     ┆ 10532  │
# │ BEL     ┆ 7854   │
# │ DNK     ┆ 5150   │
# └─────────┴────────┘

# %%
df["product_category"].value_counts().sort(by="counts", descending=True).head(10)
# Out:
# shape: (10, 2)
# ┌───────────────────────┬────────┐
# │ product_category      ┆ counts │
# │ ---                   ┆ ---    │
# │ str                   ┆ u32    │
# ╞═══════════════════════╪════════╡
# │ Lamp                  ┆ 5524   │
# │ Vacuum                ┆ 5437   │
# │ Laptop                ┆ 5092   │
# │ Hi-Fi separates       ┆ 5015   │
# │ ...                   ┆ ...    │
# │ Power tool            ┆ 4038   │
# │ Portable radio        ┆ 3968   │
# │ Food processor        ┆ 3363   │
# │ Small home electrical ┆ 2766   │
# └───────────────────────┴────────┘

# %% [markdown]
# Minor correction needed for repair barrier: one part of [the standard](https://standard.openrepair.org/standard.html) specifies `"Item too worn out"`, the other says `"Product too worn out"`, but they are the same.

# %%
df["repair_barrier_if_end_of_life"].value_counts()
# Out:
# shape: (8, 2)
# ┌──────────────────────────────────┬────────┐
# │ repair_barrier_if_end_of_life    ┆ counts │
# │ ---                              ┆ ---    │
# │ str                              ┆ u32    │
# ╞══════════════════════════════════╪════════╡
# │ Repair information not available ┆ 511    │
# │ Lack of equipment                ┆ 301    │
# │ No way to open the product       ┆ 783    │
# │ Spare parts too expensive        ┆ 700    │
# │ Spare parts not available        ┆ 1695   │
# │ Item too worn out                ┆ 515    │
# │ Product too worn out             ┆ 232    │
# │ null                             ┆ 76452  │
# └──────────────────────────────────┴────────┘

# %%
df = df.with_columns(
    pl.col("repair_barrier_if_end_of_life").map_dict(
        {"Item too worn out": "Product too worn out"},
        default=pl.col("repair_barrier_if_end_of_life"),
    )
)
df["repair_barrier_if_end_of_life"].value_counts()
# Out:
# shape: (7, 2)
# ┌──────────────────────────────────┬────────┐
# │ repair_barrier_if_end_of_life    ┆ counts │
# │ ---                              ┆ ---    │
# │ str                              ┆ u32    │
# ╞══════════════════════════════════╪════════╡
# │ No way to open the product       ┆ 783    │
# │ Product too worn out             ┆ 747    │
# │ null                             ┆ 76452  │
# │ Repair information not available ┆ 511    │
# │ Spare parts not available        ┆ 1695   │
# │ Spare parts too expensive        ┆ 700    │
# │ Lack of equipment                ┆ 301    │
# └──────────────────────────────────┴────────┘
